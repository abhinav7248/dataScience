# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav7248/dataScience/blob/main/IDSUP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

X=np.array([1,2,3])
Y=np.array([1,3,2])
plt.scatter(X,Y);

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

X=[1,2]
Y=[1,3]
plt.scatter(X,Y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

slope_current=0
intercept_current=0
LR = 0.01
iteration = 1000

for i in range(iteration):
    sum1 = 0
    sum2 = 0
    for j in range(len(X)):
        sum1 += X[j] * (Y[j] - slope_current*X[j] - intercept_current)
        sum2 += Y[j] - slope_current*X[j] - intercept_current
    slope_gradient = -(2/len(X)) * sum1
    intercept_gradient = -(2/len(X)) * sum2
    slope_current -= LR * slope_gradient
    intercept_current -= LR * intercept_gradient
    y_predicted = [slope_current*x + intercept_current for x in X]
    plt.plot(X, y_predicted)
plt.scatter(X, Y)
y_predicted = [slope_current*x + intercept_current for x in X]
plt.plot(X, y_predicted)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.scatter(X,Y)
y_predicted = [slope_current*x + intercept_current for x in X]
plt.plot(X, y_predicted);
